# %%
import pandas as pd
import numpy as np
import os
import plotly.express as px
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
manufacturer_df = pd.read_csv("../Resources/manufacturer_breakdown.csv")
manufacturer_df = manufacturer_df[['location','date','CanSino','Johnson&Johnson','Moderna','Oxford/AstraZeneca','Pfizer/BioNTech','Sinopharm/Beijing','Sinovac','Sputnik V']]

# %%
manufacturer_df["location"].unique()
# Out:
# array(['Austria', 'Belgium', 'Bulgaria', 'Chile', 'Croatia', 'Cyprus',
#        'Czechia', 'Denmark', 'Ecuador', 'Estonia', 'European Union',
#        'Finland', 'France', 'Germany', 'Hong Kong', 'Hungary', 'Iceland',
#        'Ireland', 'Italy', 'Japan', 'Latvia', 'Liechtenstein',
#        'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Norway',
#        'Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia',
#        'South Korea', 'Spain', 'Sweden', 'Switzerland', 'United States',
#        'Uruguay'], dtype=object)

# %%
manufacturer_df.fillna(float(0))
# Out:
#      location        date  CanSino  Johnson&Johnson  Moderna  \
# 0     Austria  2021-01-08      0.0              0.0      0.0
# 1     Austria  2021-01-15      0.0              0.0     87.0
# 2     Austria  2021-01-22      0.0              0.0    304.0
# 3     Austria  2021-01-29      0.0              0.0   4225.0
# 4     Austria  2021-02-05      0.0              0.0   5922.0
# ...       ...         ...      ...              ...      ...
# 4962  Uruguay  2021-09-26      0.0              0.0      0.0
# 4963  Uruguay  2021-09-27      0.0              0.0      0.0
# 4964  Uruguay  2021-09-28      0.0              0.0      0.0
# 4965  Uruguay  2021-09-29      0.0              0.0      0.0
# 4966  Uruguay  2021-09-30      0.0              0.0      0.0
#
#       Oxford/AstraZeneca  Pfizer/BioNTech  Sinopharm/Beijing    Sinovac  \
# 0                    0.0          31099.0                0.0        0.0
# 1                    0.0         115801.0                0.0        0.0
# ...

# %%
#Make eight mini-line graphs to show vaccines by vendor
by_vendor_line = make_subplots(rows=4,cols=2)
by_vendor_line =px.line(manufacturer_df, x='date', y= 'Johnson&Johnson', color ='location', title = 'Johnson & Johnson breakdown usage by country')
by_vendor_line.show()
# Out:
# <div>                            <div id="6a8ee58b-9c71-425c-809b-75c0ce4199e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a8ee58b-9c71-425c-809b-75c0ce4199e9")) {                    Plotly.newPlot(                        "6a8ee58b-9c71-425c-809b-75c0ce4199e9",                        [{"hovertemplate":"location=Austria<br>date=%{x}<br>Johnson&Johnson=%{y}<extra></extra>","legendgroup":"Austria","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"Austria","showlegend":true,"type":"scattergl","x":["2021-01-08","2021-01-15","2021-01-22","2021-01-29","2021-02-05","2021-02-12","2021-02-19","2021-02-26","2021-03-05","2021-03-12","2021-03-19","2021-03-26","2021-04-02","2021-04-09","2021-04-16","2021-04-23","2021-04-30","2021-05-07","2021
# ...

# %%
by_vendor_line = make_subplots(rows=4,cols=2)
by_vendor_line =px.line(manufacturer_df, x='date', y= 'Pfizer/BioNTech', color ='location', title = 'Pfizer/BioNTech breakdown usage by country')
by_vendor_line.show()
# Out:
# <div>                            <div id="10b5634e-1ed6-4806-b7d2-f71896fcb5c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10b5634e-1ed6-4806-b7d2-f71896fcb5c7")) {                    Plotly.newPlot(                        "10b5634e-1ed6-4806-b7d2-f71896fcb5c7",                        [{"hovertemplate":"location=Austria<br>date=%{x}<br>Pfizer/BioNTech=%{y}<extra></extra>","legendgroup":"Austria","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"Austria","showlegend":true,"type":"scattergl","x":["2021-01-08","2021-01-15","2021-01-22","2021-01-29","2021-02-05","2021-02-12","2021-02-19","2021-02-26","2021-03-05","2021-03-12","2021-03-19","2021-03-26","2021-04-02","2021-04-09","2021-04-16","2021-04-23","2021-04-30","2021-05-07","2021
# ...

# %%
by_vendor_line = make_subplots(rows=4,cols=2)
by_vendor_line =px.line(manufacturer_df, x='date', y= 'Moderna', color ='location', title = 'Moderna breakdown usage by country')
by_vendor_line.show()
# Out:
# <div>                            <div id="b2bffe60-5e4d-4cbe-853b-bcf952e45467" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2bffe60-5e4d-4cbe-853b-bcf952e45467")) {                    Plotly.newPlot(                        "b2bffe60-5e4d-4cbe-853b-bcf952e45467",                        [{"hovertemplate":"location=Austria<br>date=%{x}<br>Moderna=%{y}<extra></extra>","legendgroup":"Austria","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"Austria","showlegend":true,"type":"scattergl","x":["2021-01-08","2021-01-15","2021-01-22","2021-01-29","2021-02-05","2021-02-12","2021-02-19","2021-02-26","2021-03-05","2021-03-12","2021-03-19","2021-03-26","2021-04-02","2021-04-09","2021-04-16","2021-04-23","2021-04-30","2021-05-07","2021-05-14",
# ...

# %%
last_dates_df = pd.DataFrame()
for country in manufacturer_df["location"].unique():
    last_dates_df= last_dates_df.append(manufacturer_df[manufacturer_df["location"] == country].sort_values("date").iloc[-1:,:])

last_dates_df
# Out:
#             location        date   CanSino  Johnson&Johnson      Moderna  \
# 38           Austria  2021-09-28       NaN         308770.0    1023178.0
# 77           Belgium  2021-09-28       NaN         373670.0    1329917.0
# 117         Bulgaria  2021-09-28       NaN         193440.0     298370.0
# 395            Chile  2021-09-27  564934.0              NaN          NaN
# 435          Croatia  2021-09-28       NaN          91842.0     325583.0
# 475           Cyprus  2021-09-28       NaN          20377.0      85706.0
# 753          Czechia  2021-09-30       NaN         235128.0     920012.0
# 791          Denmark  2021-09-24       NaN          48296.0    1169890.0
# 1044         Ecuador  2021-09-29  369372.0              NaN          NaN
# 1084         Estonia  2021-09-28       NaN          50182.0     138077.0
# 1362  European Union  2021-09-30       NaN       14643957.0   56980030.0
# 1402         Finland  2021-09-28       NaN              0.0     807329.0
# ...

# %%
import matplotlib.pyplot as plt
loc = last_dates_df.groupby('location')['CanSino', 'Moderna','Oxford/AstraZeneca', 'Pfizer/BioNTech','Sinopharm/Beijing','Sinovac','Sputnik V'].max()
loc.plot(kind= 'bar', figsize = (40,20), fontsize = 25)
# Out:
# <ipython-input-9-f79e50687be0>:9: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# <AxesSubplot:xlabel='location'>

# %%
# country that uses the most of Pfizer

# %%
fig = px.histogram(last_dates_df, x="location",y='Pfizer/BioNTech', title = 'Pfizer vaccination breakdown by country')
fig.show()
# Out:
# <div>                            <div id="8b3c55ae-87ac-4c4c-a9ba-2653e1ca9028" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b3c55ae-87ac-4c4c-a9ba-2653e1ca9028")) {                    Plotly.newPlot(                        "8b3c55ae-87ac-4c4c-a9ba-2653e1ca9028",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"location=%{x}<br>sum of Pfizer/BioNTech=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":["Austria","Belgium","Bulgaria","Chile","Croatia","Cyprus","Czechia","Denmark","Ecuador","Estonia","European Union","Finland","France","Germany","Hong Kong","Hungary","Iceland"
# ...

# %%
fig = px.histogram(last_dates_df, x="location",y='Johnson&Johnson', title = 'Johnson&Johnson vaccination breakdown by country')
fig.show()
# Out:
# <div>                            <div id="ff076790-bfc6-4d63-b229-7b636738e94e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff076790-bfc6-4d63-b229-7b636738e94e")) {                    Plotly.newPlot(                        "ff076790-bfc6-4d63-b229-7b636738e94e",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"location=%{x}<br>sum of Johnson&Johnson=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":["Austria","Belgium","Bulgaria","Chile","Croatia","Cyprus","Czechia","Denmark","Ecuador","Estonia","European Union","Finland","France","Germany","Hong Kong","Hungary","Iceland"
# ...

# %%
fig = px.histogram(last_dates_df, x="location",y='Moderna', title = 'Moderna vaccination breakdown by country')
fig.show()
# Out:
# <div>                            <div id="a1cdf158-eb68-4a04-839f-c3bb71bd8b39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1cdf158-eb68-4a04-839f-c3bb71bd8b39")) {                    Plotly.newPlot(                        "a1cdf158-eb68-4a04-839f-c3bb71bd8b39",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"location=%{x}<br>sum of Moderna=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":["Austria","Belgium","Bulgaria","Chile","Croatia","Cyprus","Czechia","Denmark","Ecuador","Estonia","European Union","Finland","France","Germany","Hong Kong","Hungary","Iceland","Irelan
# ...

# %%
fig = px.histogram(last_dates_df, x="location",y='CanSino', title = 'CanSino vaccination breakdown by country')
fig.show()
# Out:
# <div>                            <div id="bb2b38b9-61a2-456c-8e18-7c9eac6e6f7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb2b38b9-61a2-456c-8e18-7c9eac6e6f7d")) {                    Plotly.newPlot(                        "bb2b38b9-61a2-456c-8e18-7c9eac6e6f7d",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"location=%{x}<br>sum of CanSino=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":["Austria","Belgium","Bulgaria","Chile","Croatia","Cyprus","Czechia","Denmark","Ecuador","Estonia","European Union","Finland","France","Germany","Hong Kong","Hungary","Iceland","Irelan
# ...

# %%
fig = px.histogram(last_dates_df, x="location",y='Oxford/AstraZeneca', title = 'Oxford/AstraZeneca vaccination breakdown by country')
fig.show()
# Out:
# <div>                            <div id="eae6be14-4511-4bcd-b17c-1ebe50ef8828" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eae6be14-4511-4bcd-b17c-1ebe50ef8828")) {                    Plotly.newPlot(                        "eae6be14-4511-4bcd-b17c-1ebe50ef8828",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"location=%{x}<br>sum of Oxford/AstraZeneca=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":["Austria","Belgium","Bulgaria","Chile","Croatia","Cyprus","Czechia","Denmark","Ecuador","Estonia","European Union","Finland","France","Germany","Hong Kong","Hungary","Icela
# ...

# %%
fig = px.histogram(last_dates_df, x="location",y='Sinopharm/Beijing', title = 'Sinopharm/Beijing vaccination breakdown by country')
fig.show()
# Out:
# <div>                            <div id="41c853be-e8a6-4bcf-9805-67376933afc9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41c853be-e8a6-4bcf-9805-67376933afc9")) {                    Plotly.newPlot(                        "41c853be-e8a6-4bcf-9805-67376933afc9",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"location=%{x}<br>sum of Sinopharm/Beijing=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":["Austria","Belgium","Bulgaria","Chile","Croatia","Cyprus","Czechia","Denmark","Ecuador","Estonia","European Union","Finland","France","Germany","Hong Kong","Hungary","Icelan
# ...

# %%
fig = px.histogram(last_dates_df, x="location",y='Sinovac', title = 'Sinovac vaccination breakdown by country')
fig.show()
# Out:
# <div>                            <div id="c531948e-069a-47ab-8706-720eb97bb47c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c531948e-069a-47ab-8706-720eb97bb47c")) {                    Plotly.newPlot(                        "c531948e-069a-47ab-8706-720eb97bb47c",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"location=%{x}<br>sum of Sinovac=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":["Austria","Belgium","Bulgaria","Chile","Croatia","Cyprus","Czechia","Denmark","Ecuador","Estonia","European Union","Finland","France","Germany","Hong Kong","Hungary","Iceland","Irelan
# ...

# %%
fig = px.histogram(last_dates_df, x="location",y='Sputnik V', title = 'Sputnik V vaccination breakdown by country')
fig.show()
# Out:
# <div>                            <div id="9b7b86d4-8542-4faf-a430-3ebdef66cf67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b7b86d4-8542-4faf-a430-3ebdef66cf67")) {                    Plotly.newPlot(                        "9b7b86d4-8542-4faf-a430-3ebdef66cf67",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"location=%{x}<br>sum of Sputnik V=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":["Austria","Belgium","Bulgaria","Chile","Croatia","Cyprus","Czechia","Denmark","Ecuador","Estonia","European Union","Finland","France","Germany","Hong Kong","Hungary","Iceland","Irel
# ...

# %%
# the most distributed/consumed drug
last_dates_df.describe()
# Out:
#              CanSino  Johnson&Johnson       Moderna  Oxford/AstraZeneca  \
# count       2.000000     3.000000e+01  3.400000e+01        3.300000e+01
# mean   467153.000000     1.525550e+06  8.445792e+06        4.812900e+06
# std    138283.216342     3.691468e+06  2.711857e+07        1.216302e+07
# min    369372.000000     0.000000e+00  3.075200e+04        8.660300e+04
# 25%    418262.500000     6.104875e+04  2.683048e+05        2.729060e+05
# 50%    467153.000000     2.142840e+05  9.715950e+05        8.479980e+05
# 75%    516043.500000     1.100403e+06  5.023679e+06        2.800983e+06
# max    564934.000000     1.497704e+07  1.513109e+08        6.713712e+07
#
#        Pfizer/BioNTech  Sinopharm/Beijing       Sinovac     Sputnik V
# count     3.800000e+01                2.0  4.000000e+00  2.000000e+00
# mean      3.087982e+07          2106111.0  9.707282e+06  1.823756e+06
# std       7.394617e+07                0.0  8.203591e+06  2.662893e+04
# ...

# %% [markdown]
# # Questions asked and answered

# %% [markdown]
# ## Question 1

# %% [markdown]
# Among the 38 countries, which country consumes which vaccine type the most?
#
# CanSino:  Chile (564.934k)
#
# Johnson&Johnson: United States (14.97704M)
#
# Moderna: United States(151.3109M). Based on internet search (it was has its manufacturing base in the US)
#
# Oxford/AstraZeneca: European Union (67.13712M) (manufactured by Swedish-British drugmaker in partnership with the University of Oxford)
#
# Pfizer/BioNTech: European Union (398.971M) (first vaccine approved for use by the European Union)
#
# Sinopharm/Beijing: European Union (2.106111M) (Developed in China by China National Pharmaceutical Group)
#
# Sinovac: Chile (20.24048M) (manufactured by Beijing-based biopharmaceuticals firm Sinovac)
#
# Sputnik V: European Union (1.248525M) (Manufactured in Russia)

# %% [markdown]
# ## Question 2

# %% [markdown]
# On the average, what is the most and least distributed/consumed drug?
#
# Most : Pfizer/BioNTech
#
# Least: Sinopharm/Beijing
